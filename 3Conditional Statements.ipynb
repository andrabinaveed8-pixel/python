# %% [markdown]
# <h2> Table of Comparison Operators </h2><p>  In the table below, a=3 and b=4.</p>
#
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td>(a != b) is true</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %% [markdown]
# ## Chaining of comparison operators

# %%
a = 5
b = 6
c = 7

# %%
a < b
# Out:
# True

# %%
a < c
# Out:
# True

# %% [markdown]
# ## Logical Operators
# - **and** : True if all are True
# - **or**  : True if at least one is True
# -**not**  : Opposite

# %%
a < b and a < c
# Out:
# True

# %%
a < c and a > c
# Out:
# False

# %%
1 < 2 and 3 < 4 and 6 > 2             #(True and True and True)
# Out:
# True

# %%
1 < 2 and 3 > 4 and 7 > 4             # (True and False and True)
# Out:
# False

# %%
1 < 2 or 3 > 4 or 7 > 4
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not 6 < 7
# Out:
# False

# %%
1 < 2 and 3 > 4 or 5 < 6
# True and False or True
# False or True
# True
# Out:
# True

# %%
# Correct username and password (Utkarsh 1234)
username = input('Enter the username : ')
password = int(input('Enter the password : '))

username == 'Liyakat' and password == 1234
# Out:
# Enter the username :  Liyakat
# Enter the password :  1234
# True

# %% [markdown]
# # ===========================================================

# %% [markdown]
# # Conditional Statements
# - if
# - if else
# - if elif else
# - nested if else

# %%
# Take the score of a candidate out of 100 as input and print Pass if the candidate scores above 50
score = int(input('Enter the score : '))

if score > 50:
    print('The cadidate has passed the exam')
# Out:
# Enter the score : 80
# The cadidate has passed the exam

# %%
score = int(input('Enter the score : '))

if score > 50:
    print('The cadidate has passed the exam')
# Out:
# Enter the score : 40

# %%
# Take the score of a candidate out of 100 as input and print Pass if the candidate scores above 50 , fail if less than 50
score = int(input('Enter the score : '))

if score > 50:
    print('The cadidate has passed the exam')
else:
    print('The cadidate has failed the exam')
# Out:
# Enter the score : 80
# The cadidate has passed the exam

# %%
score = int(input('Enter the score : '))

if score > 50:
    print('The cadidate has passed the exam')
else:
    print('The cadidate has failed the exam')
# Out:
# Enter the score : 40
# The cadidate has failed the exam

# %%
# indentation
if True:
    print('Hello')
    print('Good morning')
    print('How are you')
print('Outside if block')
# Out:
# Hello
# Good morning
# How are you
# Outside if block

# %%
if False:
    print('Hello')
    print('Good morning')
    print('How are you')
print('Outside if block')
# Out:
# Outside if block

# %%
# Assume correct Username and password to be Utkarsh , 12345
# Take username and password as input from user and print access granted if the they are correct otherwise access denied

username = input('Enter the username : ')
password = int(input('Enter the password : '))

if username == 'naveed' and password == 12345:
    print('Access Granted')
else:
    print('Access Denied')
# Out:
# Enter the username :  naveed
# Enter the password :  12345
# Access Denied

# %%
# Complex conditions
age = 25
income = 50000
credit_score = 700

if (age >= 21 and income >= 30000) or credit_score >= 650:
    print("Loan approved")
else:
    print("Loan denied")

# Using parentheses for clarity
x = 10
y = 20
z = 30

if (x > 5 and y < 25) or z == 30:
    print("Condition satisfied")

# %%
color = input("enter color: ")
if color == "red":
    print("stop")

elif color == "yellow":
    print("be ready")
else:
    print("go")
# Out:
# enter color:  red
# stop

# %%
name = input("who is this ? : ")
if name == "naveed":
    print("welcome naveed")
elif name == "rohan":
    print("welcome rohan")
elif name == "owais":
    print("welcome owais")
else:
    print("Go back you are not invited")
# Out:
# who is this ? :  naveed
# welcome naveed

# %%
# Take scores of two students out of 100 as input and print who scored higher
marks1 = int(input('Enter the marks of first student (out of 100) : '))
marks2 = int(input('Enter the marks of second student (out of 100) : '))

if marks1 > marks2:
    print('First Student has scored higher', marks1)
else:
    print('Second Student has scored higher', marks2)
# Out:
# Enter the marks of first student (out of 100) : 90
# Enter the marks of second student (out of 100) : 80
# First Student has scored higher 90

# %%
name = input("who is this ? : ")
if name == "naveed":
    print("welcome",name)
else:
    print("go back, you are not invited sir/madam")
# Out:
# who is this ? :  rohan
# go back, you are not invited sir/madam

# %%
# take the numbers and an arthimatic operations from user
# and print the result of correspomding operation
# (+,-,*,/)
#ans--------------------------------------------------------
# Get input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform calculation based on operation
if operation == '+':
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operation == '-':
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operation == '*':
    result = num1 * num2
    print(f"{num1} * {num2} = {result}")
elif operation == '/':
    if num2 != 0:  # Check for division by zero
        result = num1 / num2
        print(f"{num1} / {num2} = {result}")
    else:
        print("Error: Cannot divide by zero!")
else:
    print("Invalid operation! Please enter +, -, *, or /")

# %%
num1 = float(input("enter any number"))
num2 = float(input("enter 2nd number"))
operator = input("enter operator")
if operator == "+":
    print(num1+num2)
elif operator == "-":
    print(num1-num2)
elif operator == "/":
     print(num1/num2)
elif operator == "*":
    print(num1*num2)
else:
    print("invalid operator")
# Out:
# enter any number 10.6
# enter 2nd number 10.7
# enter operator +
# 21.299999999999997

# %%
#for zero division error
num1 = float(input("enter any number"))
num2 = float(input("enter 2nd number"))
operator = input("enter operator")
if operator == "+":
    print(num1+num2)
elif operator == "-":
    print(num1-num2)
elif operator == "/":
     print(num1/num2)
    if (num2 == 0):
        print("second number should not be zero")
    else:
        print("result is: " num1/num2)
elif operator == "*":
    print(num1*num2)
else:
    print("invalid operator")
# Out:
#   File <string>:11
#     if (num2 == 0):
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
username = input("enter username")
password = input("enter password")
if username == "abcdef" and password == "abc@100":
    print("login successful")
else:
    if username != "abcdef" and password != "abc@100":
        print("both incorrect")
    elif username != "abcdef":
        print("incorrect username")
    else:
        print("password is incorrect")

# %%
marks1 = int(input('Enter the marks of first student (out of 100) : '))
marks2 = int(input('Enter the marks of second student (out of 100) : '))

if marks1 > marks2:
    print('First student has scored higher : ', marks1)
elif marks2 > marks1:
    print('Second student has scored higher : ', marks2)
else:
    print('Both the students have same scores')
# Out:
# Enter the marks of first student (out of 100) : 90
# Enter the marks of second student (out of 100) : 90
# Both the students have same scores

# %%
name = input('Who is this : ')

if name == 'Umer':
    print('Welcome umer')
elif name == 'Maseerah':
    print('Welcome Maseerah')
elif name == 'Maryam':
    print('Welcome Maryam')
elif name == 'Parvaiz':
    print('Welcome parvaiz')
else:
    print('Go back , you are not invited, bin bulaye mehman a jate hai')
# Out:
# Who is this :  Liyakat
# Go back , you are not invited, bin bulaye mehman a jate hai

# %%
name = input('Who is this : ')

invited_candidates = ['umer', 'Maryam', 'Maseerah', 'Parvaiz']
if name in invited_candidates:
    print('Welcome', name)
else:
    print('You are not invited')
# Out:
# Who is this :  liyakat
# You are not invited

# %%
# Take a number as input and print whether it is even or odd
num = int(input('Enter the number : '))

if num % 2 == 0:
    print(num,'is even')
else:
    print(num,'is odd')
# Out:
# Enter the number : 11
# 11 is odd

# %%
# Take two numbers and an arithmatic operator as input from the user and print result of the correspoding operation
a = int(input('Enter the first  number : '))
b = int(input('Enter the second number : '))
op = input('Enter the operator : ')

if op == '+':
    print(a + b)
elif op == '-':
    print(a - b)
elif op == '*':
    print(a * b)
elif op == '/':
    print(a / b)
elif op == '//':
    print(a // b)
elif op == '**':
    print(a ** b)
elif op == '%':
    print(a % b)
else:
    print('Invalid operator')
# Out:
# Enter the first  number : 2
# Enter the second number : 6
# Enter the operator : **
# 64

# %%
# Take three integers as input and print the largest
a = int(input('Enter the first  number : '))
b = int(input('Enter the second number : '))
c = int(input('Enter the third  number : '))

if a > b and a > c:
    print(a,'is largest')
elif b > c:
    print(b,'is largest')
else:
    print(c,'is largest')
# Out:
# Enter the first  number : 70
# Enter the second number : 80
# Enter the third  number : 60
# 80 is largest

# %%
# Assume correct Username and password to be Utkarsh , 12345
# Take username and password as input from user and print access granted if the they are correct otherwise print incorrect username or incorect password

username = input('Enter the username : ')
password = int(input('Enter the password : '))

if username == 'Liyakat' and password == 12345:
    print('Access Granted')
else:
    if username != 'Utkarsh':
        print('Incorrect Username')
    else:
        print('Incorrect Password')
# Out:
# Enter the username :  Liyakat
# Enter the password :  12345
# Access Granted

# %%
username = input('Enter the username : ')
password = int(input('Enter the password : '))

if username == 'Liyakat' and password == 12345:
    print('Access Granted')
else:
    if username != 'Liyakat' and password != 12345:
        print('Username and password both are incorrect')
    elif username != 'Liyakat':
        print('Incorrect Username')
    else:
        print('Incorrect Password')
# Out:
# Enter the username :  liyakat
# Enter the password :  111
# Username and password both are incorrect

# %%
# Take three integers as input and print the largest
a = int(input('Enter the first  number : '))
b = int(input('Enter the second number : '))
c = int(input('Enter the third  number : '))

if a > b:
    if a > c:
        print(a,'is largest')
    else:
        print(c, 'is largest')
else:
    if b > c:
        print(b,'is largest')
    else:
        print(c, 'is largest')
# Out:
# Enter the first  number : 10
# Enter the second number : 30
# Enter the third  number : 20
# 30 is largest

# %%
# Take three numbers as input and find second largest
a = int(input('Enter the first  number : '))
b = int(input('Enter the second number : '))
c = int(input('Enter the third  number : '))

if a > b and a > c:
    if b > c:
        print(b, 'is second largest')
    else:
        print(c, 'is second largest')
elif b > c:
    if a > c:
        print(a, 'is second largest')
    else:
        print(c, 'is second largest')
else:
    if a > b:
        print(a, 'is second largest')
    else:
        print(b, 'is second largest')
# Out:
# Enter the first  number : 40
# Enter the second number : 40
# Enter the third  number : 20
# 40 is second largest

# %% [markdown]
# ## SHORT HAND IF ELSE
# - If you have only one statement to execute, one for if, and one for else, you can put it all on the same line:
# - This technique is known as Ternary Operators, or Conditional Expressions.

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# ## The pass Statement
# - if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.

# %%
a = 33
b = 200

if b > a:
  pass
